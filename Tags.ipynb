# %%
import pandas as pd

# %%
# Load entire file
chunker = pd.read_csv("/home/pi/Downloads/tags-20210226.csv", chunksize=10000)
tags = pd.concat(chunker, ignore_index=True)

# %%
tags
# Out:
#                 id      type                                name  canonical  \
# 0                1     Media                            TV Shows       True
# 1                2     Media                              Movies       True
# 2                3     Media                  Books & Literature       True
# 3                4     Media  Cartoons & Comics & Graphic Novels       True
# 4                5     Media                       Anime & Manga       True
# ...            ...       ...                                 ...        ...
# 14467133  55395603  Freeform                            Redacted      False
# 14467134  55395606  Freeform                            Redacted      False
# 14467135  55395609  Freeform                            Redacted      False
# 14467136  55395612  Freeform                            Redacted      False
# 14467137  55395615  Freeform                            Redacted      False
#
#           cached_count  merger_id
# ...

# %%
tag_type = tags.type.unique()
tag_type
# Out:
# array(['Media', 'Rating', 'ArchiveWarning', 'Category', 'Character',
#        'Fandom', 'Relationship', 'Freeform', 'UnsortedTag'], dtype=object)

# %%
# Test: Loop tag_type
for i in tag_type:
    print(i)
# Out:
# Media
# Rating
# ArchiveWarning
# Category
# Character
# Fandom
# Relationship
# Freeform
# UnsortedTag

# %%
# Select tags by type
tags[tags['type'] == 'Media']
# Out:
#           id   type                                name  canonical  \
# 0          1  Media                            TV Shows       True
# 1          2  Media                              Movies       True
# 2          3  Media                  Books & Literature       True
# 3          4  Media  Cartoons & Comics & Graphic Novels       True
# 4          5  Media                       Anime & Manga       True
# 5          6  Media                       Music & Bands       True
# 6          7  Media           Celebrities & Real People       True
# 7          8  Media                         Other Media       True
# 388      476  Media                         Video Games       True
# 4510    5451  Media                            No Media       True
# 8150    9971  Media               Uncategorized Fandoms       True
# 23433  30198  Media                             Theater       True
#
#        cached_count  merger_id
# 0               910        NaN
# ...

# %%
# Test: write to local file

path = 'Media.csv'
tags[tags['type'] == 'Media'].to_csv(path, index=False)

# %%
# Loop action for all tag types
for i in tag_type:
    path = f"tags-{i}.csv"
    tags[tags['type'] == i].to_csv(path, index=False)
